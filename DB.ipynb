# %%
import duckdb

import numpy as np
import pandas as pd
from sklearn.impute import SimpleImputer

# %%
df = pd.read_csv("poverty_raw_data.csv")
df.head(10)
# Out:
#    record_id region_code country_name country_code survey_acronym  \
# 0          1         NaN       Angola          AGO            HBS
# 1          2         SSA       Angola          AGO      IBEP-MICS
# 2          3         SSA       Angola          AGO          IDREA
# 3          4         ECA      Armenia          ARM           ILCS
# 4          5         ECA      Albania          ALB            EWS
# 5          6         ECA      Albania          ALB           LSMS
# 6          7         ECA      Armenia          ARM           ILCS
# 7          8         NaN      Albania          ALB           LSMS
# 8          9         ECA      Armenia          ARM           ILCS
# 9         10         ECA      Albania          ALB           LSMS
#
#    reporting_year reporting_level survey_coverage  survey_year welfare_type  \
# 0            2000        national        national      2000.21  consumption
# 1            2008        national        national      2008.50  consumption
# 2            2018        national        national      2018.17  consumption
# 3            2012        national        national      2012.00  consumption
# 4            1996        national        national      1996.00  consumption
# 5            2002        national        national      2002.00  consumption
# 6            2013        national        national      2013.00  consumption
# 7            2005        national        national      2005.00  consumption
# 8            2014        national        national      2014.00  consumption
# 9            2008        national        national      2008.00  consumption
#
#    ...   decile9  decile10       cpi         ppp  reporting_pop  \
# 0  ...  0.158687  0.402455  0.014200  107.269989       16394062
# 1  ...  0.162333  0.323117  0.303449  107.269989       21691522
# 2  ...  0.159390  0.396244  1.231024  107.269989       31273533
# 3  ...  0.141960  0.245402  0.888864  167.312210        2914421
# 4  ...  0.148995  0.212156  0.399635   50.357372        3168033
# 5  ...  0.149251  0.254356  0.701637   50.357372        3051010
# 6  ...  0.147086  0.246855  0.940327  167.312210        2901385
# 7  ...  0.148339  0.243412  0.753958   50.357372        3011487
# 8  ...  0.143123  0.257440  0.968361  167.312210        2889930
# 9  ...  0.145352  0.244583  0.820114   50.357372        2947314
#
#    reporting_gdp  reporting_pce  is_interpolated  distribution_type  \
# 0    1840.353828            NaN                0              micro
# 1    3061.636272    1216.312411                0              micro
# 2    2677.249833    1548.153535                0              micro
# 3    3278.670451    2953.453311                0              micro
# 4    1633.552004    1716.336806                0              micro
# 5    2247.498086    1685.203083                0              micro
# 6    3402.083858    3017.291522                0              micro
# 7    2675.508644    2079.203480                0              micro
# 8    3538.529395    3077.428042                0              micro
# 9    3298.478917    2820.279521                0              micro
#
#    estimation_type
# 0           survey
# 1           survey
# 2           survey
# 3           survey
# 4           survey
# 5           survey
# 6           survey
# 7           survey
# 8           survey
# 9           survey
#
# [10 rows x 40 columns]

# %%
query1 = duckdb.query('''SELECT
            country_name,
            survey_acronym,
            survey_year
            FROM df
            WHERE region_code ='LAC' and
            survey_coverage = 'national'
            GROUP BY 
            country_name,
            survey_acronym,
            survey_year;
            ''')
query1
# Out:
# ┌─────────────────────┬────────────────┬─────────────┐
# │    country_name     │ survey_acronym │ survey_year │
# │       varchar       │    varchar     │   double    │
# ├─────────────────────┼────────────────┼─────────────┤
# │ Bolivia             │ EH             │      2017.0 │
# │ Brazil              │ PNAD           │      1983.0 │
# │ Brazil              │ PNADC-E1       │      2016.0 │
# │ Brazil              │ PNADC-E1       │      2017.0 │
# │ Brazil              │ PNADC-E1       │      2018.0 │
# │ Brazil              │ PNADC-E5       │      2021.0 │
# │ Belize              │ LFS            │      1997.0 │
# │ Brazil              │ PNAD           │      1998.0 │
# │ Brazil              │ PNAD           │      1999.0 │
# │ Brazil              │ PNAD           │      2007.0 │
# │   ·                 │ ·              │         ·   │
# │   ·                 │ ·              │         ·   │
# │   ·                 │ ·              │         ·   │
# │ Paraguay            │ EH             │      1995.0 │
# │ El Salvador         │ EHPM           │      2019.0 │
# │ El Salvador         │ EHPM           │      2021.0 │
# │ El Salvador         │ EHPM           │      2009.0 │
# │ El Salvador         │ EHPM           │      2011.0 │
# │ Trinidad and Tobago │ PHC            │      1992.0 │
# │ Uruguay             │ ECH            │      2012.0 │
# │ Paraguay            │ EPH            │      2017.0 │
# │ Paraguay            │ EPH            │      2018.0 │
# │ Paraguay            │ EPH            │      2022.0 │
# ├─────────────────────┴────────────────┴─────────────┤
# │ 382 rows (20 shown)                      3 columns │
# └────────────────────────────────────────────────────┘

# %%
query1 = duckdb.query('''SELECT
            country_name,
            AVG(reporting_pce) AS min_avg_reporting_pce
            FROM df
            WHERE region_code ='SSA' 
            GROUP BY 
            country_name
            HAVING
            AVG(reporting_pce) <= ALL 
                (SELECT avg_reporting_pce FROM
                    (SELECT
                    country_name,
                    AVG(reporting_pce) AS avg_reporting_pce
                    FROM df
                    WHERE region_code ='SSA'
                    GROUP BY 
                    country_name)
                    WHERE avg_reporting_pce IS NOT NULL)''')
query1
# Out:
# ┌──────────────────┬───────────────────────┐
# │   country_name   │ min_avg_reporting_pce │
# │     varchar      │        double         │
# ├──────────────────┼───────────────────────┤
# │ Congo, Dem. Rep. │          305.26031975 │
# └──────────────────┴───────────────────────┘

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2318 entries, 0 to 2317
# Data columns (total 40 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   record_id             2318 non-null   int64
#  1   region_code           2216 non-null   object
#  2   country_name          2318 non-null   object
#  3   country_code          2318 non-null   object
#  4   survey_acronym        2318 non-null   object
#  5   reporting_year        2318 non-null   int64
#  6   reporting_level       2318 non-null   object
#  7   survey_coverage       2244 non-null   object
#  8   survey_year           2318 non-null   float64
#  9   welfare_type          2318 non-null   object
#  10  survey_comparability  2318 non-null   int64
#  11  comparable_spell      2318 non-null   object
#  12  poverty_line          2318 non-null   float64
#  13  headcount             2318 non-null   float64
#  14  poverty_gap           2318 non-null   float64
#  15  poverty_severity      2318 non-null   float64
#  16  watts                 2318 non-null   float64
#  17  mean                  2318 non-null   float64
#  18  median                2318 non-null   float64
#  19  mld                   2318 non-null   float64
#  20  gini                  2318 non-null   float64
#  21  polarization          2318 non-null   float64
#  22  decile1               2318 non-null   float64
#  23  decile2               2318 non-null   float64
#  24  decile3               2318 non-null   float64
#  25  decile4               2318 non-null   float64
#  26  decile5               2318 non-null   float64
#  27  decile6               2318 non-null   float64
#  28  decile7               2318 non-null   float64
#  29  decile8               2318 non-null   float64
#  30  decile9               2318 non-null   float64
#  31  decile10              2318 non-null   float64
#  32  cpi                   2318 non-null   float64
#  33  ppp                   2318 non-null   float64
#  34  reporting_pop         2318 non-null   int64
#  35  reporting_gdp         2318 non-null   float64
#  36  reporting_pce         2058 non-null   float64
#  37  is_interpolated       2318 non-null   int64
#  38  distribution_type     2318 non-null   object
#  39  estimation_type       2318 non-null   object
# dtypes: float64(25), int64(5), object(10)
# memory usage: 724.5+ KB

# %%
df[df["region_code"].isna()]
# Out:
#      record_id region_code country_name country_code survey_acronym  \
# 0            1         NaN       Angola          AGO            HBS
# 7            8         NaN      Albania          ALB           LSMS
# 13          14         NaN      Albania          ALB            HBS
# 14          15         NaN      Albania          ALB         SILC-C
# 23          24         NaN      Armenia          ARM           ILCS
# ..         ...         ...          ...          ...            ...
# 680        681         NaN      Finland          FIN        IDS-LIS
# 685        686         NaN        Spain          ESP        EU-SILC
# 837        838         NaN        Gabon          GAB           EGEP
# 843        844         NaN        Gabon          GAB           EGEP
# 958        959         NaN       Guyana          GUY          GLSMS
#
#      reporting_year reporting_level survey_coverage  survey_year welfare_type  \
# 0              2000        national        national      2000.21  consumption
# 7              2005        national        national      2005.00  consumption
# 13             2016        national        national      2016.00  consumption
# 14             2016        national        national      2016.00       income
# 23             2018        national        national      2018.00  consumption
# ..              ...             ...             ...          ...          ...
# 680            1995        national        national      1995.00       income
# 685            2012        national        national      2012.00       income
# 837            2005        national        national      2005.00  consumption
# 843            2017        national        national      2017.00  consumption
# 958            1998        national        national      1998.00       income
#
#      ...   decile9  decile10       cpi         ppp  reporting_pop  \
# 0    ...  0.158687  0.402455  0.014200  107.269989       16394062
# 7    ...  0.148339  0.243412  0.753958   50.357372        3011487
# 13   ...  0.161388  0.250496  0.979810   50.357372        2876101
# 14   ...  0.166304  0.274669  0.979810   50.357372        2876101
# 23   ...  0.138003  0.291994  1.025202  167.312210        2836557
# ..   ...       ...       ...       ...         ...            ...
# 680  ...  0.139024  0.205439  4.323055    0.933301        5107790
# 685  ...  0.158622  0.257865  0.975502    0.702861       46773055
# 837  ...  0.155274  0.331460  0.776824  319.160339        1458353
# 843  ...  0.166351  0.277260  1.000000  319.160339        2140215
# 958  ...  0.157220  0.344461  0.439959  115.626328         756697
#
#      reporting_gdp  reporting_pce  is_interpolated  distribution_type  \
# 0      1840.353828            NaN                0              micro
# 7      2675.508644    2079.203480                0              micro
# 13     4090.372739    3262.756967                0              micro
# 14     4090.372739    3262.756967                0              micro
# 23     4215.899398    3392.411750                0              micro
# ..             ...            ...              ...                ...
# 680   29912.897970   15581.824660                0              micro
# 685   24634.962090   14704.794250                0              micro
# 837    7155.365485    2150.297891                0              micro
# 843    6893.384327    2612.306082                0              micro
# 958    3741.813067            NaN                0              micro
#
#      estimation_type
# 0             survey
# 7             survey
# 13            survey
# 14            survey
# 23            survey
# ..               ...
# 680           survey
# 685           survey
# 837           survey
# 843           survey
# 958           survey
#
# [102 rows x 40 columns]

# %% [markdown]
# Approaches for Dealing with NULLs
#
# Ignoring them
#
# Deleting the rows containing them (listwise deletion)
#
# Imputation based on theencie)scolumn
#
# Imputation base on othe
# (Imputation Based on Functional
# Dependencie)r columns

# %%
region_codes = df[~df['region_code'].isna()].set_index("country_code")['region_code'].to_dict()

region_country_codes = df[df['region_code'].isna()]['country_code'].map(region_codes)
df['region_code'] = df['region_code'].fillna(region_country_codes)

# %%
df.loc[df['country_name'] == 'Gabon', 'region_code'] = df.loc[df['country_name'] == 'Gabon', 'region_code'].fillna('SSA')
df.loc[df['country_name'] == 'Guyana', 'region_code'] = df.loc[df['country_name'] == 'Guyana', 'region_code'].fillna('LAC')

# %%
df.groupby("survey_coverage")["record_id"].count()
# Out:
# survey_coverage
# national    2186
# rural          2
# urban         56
# Name: record_id, dtype: int64

# %% [markdown]
# Simple Univariate Imputation: Most frequent value observed in the column

# %%
df["survey_coverage"] = df["survey_coverage"].fillna("national")

# %%
df["reporting_pce"] = df.groupby("country_code")["reporting_pce"].transform(lambda x: x.fillna(x.mean()))

# %%
df["reporting_pce"] = df.groupby("region_code")["reporting_pce"].transform(lambda x: x.fillna(x.mean()))

# %%
duckdb.query('''SELECT
            country_name,
            survey_acronym,
            survey_year
            FROM df
            WHERE region_code ='LAC' and
            survey_coverage = 'national'
            GROUP BY 
            country_name,
            survey_acronym,
            survey_year
            ORDER BY country_name, survey_year
            ''')
# Out:
# ┌───────────────┬────────────────┬─────────────┐
# │ country_name  │ survey_acronym │ survey_year │
# │    varchar    │    varchar     │   double    │
# ├───────────────┼────────────────┼─────────────┤
# │ Argentina     │ EPHC-S2        │      2016.0 │
# │ Belize        │ LFS            │      1993.0 │
# │ Belize        │ LFS            │      1994.0 │
# │ Belize        │ HBS            │      1995.0 │
# │ Belize        │ SLC            │      1996.0 │
# │ Belize        │ LFS            │      1997.0 │
# │ Belize        │ LFS            │      1998.0 │
# │ Belize        │ LFS            │      1999.0 │
# │ Bolivia       │ ENE            │      1997.0 │
# │ Bolivia       │ ECH            │      1999.0 │
# │    ·          │  ·             │         ·   │
# │    ·          │  ·             │         ·   │
# │    ·          │  ·             │         ·   │
# │ Venezuela, RB │ EHM            │      1992.0 │
# │ Venezuela, RB │ EHM            │      1995.0 │
# │ Venezuela, RB │ EHM            │      1998.0 │
# │ Venezuela, RB │ EHM            │      1999.0 │
# │ Venezuela, RB │ EHM            │      2001.0 │
# │ Venezuela, RB │ EHM            │      2002.0 │
# │ Venezuela, RB │ EHM            │      2003.0 │
# │ Venezuela, RB │ EHM            │      2004.0 │
# │ Venezuela, RB │ EHM            │      2005.0 │
# │ Venezuela, RB │ EHM            │      2006.0 │
# ├───────────────┴────────────────┴─────────────┤
# │ 402 rows (20 shown)                3 columns │
# └──────────────────────────────────────────────┘

# %%
duckdb.query('''SELECT
            country_name,
            AVG(reporting_pce) AS min_avg_reporting_pce
            FROM df
            WHERE region_code ='SSA' 
            GROUP BY 
            country_name
            HAVING
            AVG(reporting_pce) <= ALL 
                (SELECT avg_reporting_pce FROM
                    (SELECT
                    country_name,
                    AVG(reporting_pce) AS avg_reporting_pce
                    FROM df
                    WHERE region_code ='SSA'
                    GROUP BY 
                    country_name)
                    WHERE avg_reporting_pce IS NOT NULL)''')
# Out:
# ┌──────────────────┬───────────────────────┐
# │   country_name   │ min_avg_reporting_pce │
# │     varchar      │        double         │
# ├──────────────────┼───────────────────────┤
# │ Congo, Dem. Rep. │          305.26031975 │
# └──────────────────┴───────────────────────┘

# %% [markdown]
# 1. country_code- country_name
# 2. country_code - region_code

# %%
countries = df[["country_code", "country_name"]].drop_duplicates()
regions = df[["country_code", "region_code"]].drop_duplicates()
df = df.drop(["country_name", "region_code"], axis=1)

# %%
duckdb.query('''SELECT
            C.country_name,
            survey_acronym,
            survey_year
            FROM df, regions AS R, countries AS C
            WHERE df.country_code = R.country_code AND
                df.country_code = C.country_code AND
                R.region_code ='LAC' AND
                survey_coverage = 'national'
            GROUP BY 
            country_name,
            survey_acronym,
            survey_year
            ORDER BY C.country_name, survey_year
            ''')
# Out:
# ┌───────────────┬────────────────┬─────────────┐
# │ country_name  │ survey_acronym │ survey_year │
# │    varchar    │    varchar     │   double    │
# ├───────────────┼────────────────┼─────────────┤
# │ Argentina     │ EPHC-S2        │      2016.0 │
# │ Belize        │ LFS            │      1993.0 │
# │ Belize        │ LFS            │      1994.0 │
# │ Belize        │ HBS            │      1995.0 │
# │ Belize        │ SLC            │      1996.0 │
# │ Belize        │ LFS            │      1997.0 │
# │ Belize        │ LFS            │      1998.0 │
# │ Belize        │ LFS            │      1999.0 │
# │ Bolivia       │ ENE            │      1997.0 │
# │ Bolivia       │ ECH            │      1999.0 │
# │    ·          │  ·             │         ·   │
# │    ·          │  ·             │         ·   │
# │    ·          │  ·             │         ·   │
# │ Venezuela, RB │ EHM            │      1992.0 │
# │ Venezuela, RB │ EHM            │      1995.0 │
# │ Venezuela, RB │ EHM            │      1998.0 │
# │ Venezuela, RB │ EHM            │      1999.0 │
# │ Venezuela, RB │ EHM            │      2001.0 │
# │ Venezuela, RB │ EHM            │      2002.0 │
# │ Venezuela, RB │ EHM            │      2003.0 │
# │ Venezuela, RB │ EHM            │      2004.0 │
# │ Venezuela, RB │ EHM            │      2005.0 │
# │ Venezuela, RB │ EHM            │      2006.0 │
# ├───────────────┴────────────────┴─────────────┤
# │ 402 rows (20 shown)                3 columns │
# └──────────────────────────────────────────────┘

# %%
duckdb.query('''SELECT
            C.country_name,
            AVG(reporting_pce) AS min_avg_reporting_pce
            FROM df, regions AS R, countries AS C
            WHERE df.country_code = R.country_code AND R.region_code ='SSA' AND
                df.country_code = C.country_code
            GROUP BY 
            C.country_name
            HAVING
            AVG(reporting_pce) <= ALL 
                (SELECT avg_reporting_pce FROM
                    (SELECT
                    df.country_code,
                    AVG(reporting_pce) AS avg_reporting_pce
                    FROM df, regions AS R
                    WHERE df.country_code = R.country_code AND R.region_code ='SSA'
                    GROUP BY 
                    df.country_code)
                    WHERE avg_reporting_pce IS NOT NULL)''')
# Out:
# ┌──────────────────┬───────────────────────┐
# │   country_name   │ min_avg_reporting_pce │
# │     varchar      │        double         │
# ├──────────────────┼───────────────────────┤
# │ Congo, Dem. Rep. │          305.26031975 │
# └──────────────────┴───────────────────────┘
